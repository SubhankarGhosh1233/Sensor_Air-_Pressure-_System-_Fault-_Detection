# %%
from sensor.predictor import ModelResolver

# %%
model_resolver = ModelResolver()

# %%
model_resolver.get_latest_save_model_path()
# Out:
# 'saved_models\\0\\model\\model.pkl'

# %%
model_resolver.get_latest_save_transformer_path()
# Out:
# 'saved_models\\0\\transformer\\transformer.pkl'

# %%
model_resolver.get_latest_save_target_encoder_path()
# Out:
# 'saved_models\\0\\target_encoder\\target_encoder.pkl'

# %%
model_resolver.get_latest_model_path()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model_resolver.get_latest_model_path()
#
# File e:\ABBC\Aps_Fault_Detection\sensor\predictor.py:40, in ModelResolver.get_latest_model_path(self)
#      38     return os.path.join(latest_dir,self.model_dir_name,MODEL_FILE_NAME)
#      39 except Exception as e:
# ---> 40     raise e
#
# File e:\ABBC\Aps_Fault_Detection\sensor\predictor.py:37, in ModelResolver.get_latest_model_path(self)
#      35     latest_dir = self.get_latest_dir_path()
#      36     if latest_dir is None:
# ---> 37         raise Exception(f"Model is not available")
#      38     return os.path.join(latest_dir,self.model_dir_name,MODEL_FILE_NAME)
#      39 except Exception as e:
#
# Exception: Model is not available

# %%
model_resolver.get_latest_target_encoder_path()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model_resolver.get_latest_target_encoder_path()
#
# File e:\ABBC\Aps_Fault_Detection\sensor\predictor.py:60, in ModelResolver.get_latest_target_encoder_path(self)
#      58     return os.path.join(latest_dir,self.target_encoder_dir_name,TARGET_ENCODER_OBJECT_FILE_NAME)
#      59 except Exception as e:
# ---> 60     raise e
#
# File e:\ABBC\Aps_Fault_Detection\sensor\predictor.py:57, in ModelResolver.get_latest_target_encoder_path(self)
#      55     latest_dir = self.get_latest_dir_path()
#      56     if latest_dir is None:
# ---> 57         raise Exception(f"Target encoder is not available")
#      58     return os.path.join(latest_dir,self.target_encoder_dir_name,TARGET_ENCODER_OBJECT_FILE_NAME)
#      59 except Exception as e:
#
# Exception: Target encoder is not available

# %%
model_resolver.get_latest_transformer_path()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model_resolver.get_latest_transformer_path()
#
# File e:\ABBC\Aps_Fault_Detection\sensor\predictor.py:50, in ModelResolver.get_latest_transformer_path(self)
#      48     return os.path.join(latest_dir,self.transformer_dir_name,TRANSFORMER_OBJECT_FILE_NAME)
#      49 except Exception as e:
# ---> 50     raise e
#
# File e:\ABBC\Aps_Fault_Detection\sensor\predictor.py:47, in ModelResolver.get_latest_transformer_path(self)
#      45     latest_dir = self.get_latest_dir_path()
#      46     if latest_dir is None:
# ---> 47         raise Exception(f"Transformer is not available")
#      48     return os.path.join(latest_dir,self.transformer_dir_name,TRANSFORMER_OBJECT_FILE_NAME)
#      49 except Exception as e:
#
# Exception: Transformer is not available

# %%
model_resolver.get_latest_dir_path()
